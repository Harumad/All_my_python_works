# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('hospital_data.csv')
# Display the first few rows of the dataset 

df
# Out:
#     patient_id      patient_name   age  gender   department  visit_date  \
# 0          301      kwame asante  34.0    Male   Cardiology  2025-01-15
# 1          302    AKOSUA  MENSAH  28.0       f   pediatrics  2025-02-03
# 2          303       Yaw Boateng  45.0    MALE  ORTHOPEDICS  2025-01-22
# 3          304         Ama Owusu   NaN  Female      General  15/03/2025
# 4          305        KOFI DARKO  67.0       M   cardiology  2025-02-18
# 5          303      kwame asante  34.0    Male   Cardiology  2025-01-15
# 6          306          Esi Adu   23.0  FEMALE   PEDIATRICS  20/02/2025
# 7          307     Nana Frimpong  56.0    male      general  2025-03-05
# 8          308     ADWOA SARPONG  41.0       F  Orthopedics  2025-01-30
# 9          309       fiifi quaye   NaN    Male      GENERAL  12/04/2025
# 10         310   BISMARK ANKRAH   38.0  female   cardiology  2025-02-25
# 11         311        Akua  Kyei  29.0  FEMALE   Pediatrics  08/03/2025
# 12         312        kojo  poku  52.0       M  ORTHOPEDICS  2025-04-10
# 13         313     Serwa Tetteh   19.0       f      general  25/01/2025
# 14         314       Kweku Antwi  73.0    MALE   Cardiology  05/04/2025
# 15         315       EFUA MENSAH   NaN  Female   PEDIATRICS  2025-03-15
# 16         316        yaw  asare  31.0    male  orthopedics  18/02/2025
# 17         317        Ama Darko   44.0       F      General  2025-04-22
# 18         318        Kofi Owusu  26.0    MALE   CARDIOLOGY  10/03/2025
# 19         319       ABENA QUAYE  60.0  Female   pediatrics  28/01/2025
# 20         320   kwabena  ankrah  35.0       m  Orthopedics  2025-02-14
# 21         321  NANA AMA BOATENG   NaN  FEMALE      GENERAL  22/04/2025
# 22         322    esi  frimpong   48.0    Male   cardiology  2025-03-08
# 23         323    Bismark Asante  22.0       f   Pediatrics  14/02/2025
# 24         324      akosua  kyei  55.0    MALE  ORTHOPEDICS  30/03/2025
# 25         325       KOJO MENSAH  39.0  female      general  2025-01-19
# 26         326         kweku adu  27.0       M   Cardiology  11/04/2025
# 27         327      ADWOA TETTEH   NaN  Female   PEDIATRICS  2025-02-07
# 28         328       fiifi  poku  50.0    male  orthopedics  23/03/2025
# 29         329      Yaw Sarpong   33.0       F      General  06/02/2025
# 30         330        AKUA ANTWI  42.0    MALE   CARDIOLOGY  2025-04-15
# 31         331       kofi  asare  25.0  female   pediatrics  17/01/2025
# 32         332         ESI DARKO  58.0       m  Orthopedics  2025-03-25
# 33         333       nana  quaye   NaN       F      GENERAL  09/02/2025
# 34         334     Bismark Kyei   36.0    Male   cardiology  2025-04-03
#
#    blood_pressure weight_kg consultation_fee  satisfaction_score  \
# 0          120/80     75 kg          GHS 150                 8.0
# 1          110/70      62kg          GHS 100                 9.0
# 2          140/90     88 KG          GHS 200                 NaN
# 3          130/85     70 kg          GHS 150                 7.0
# 4         180/110      95kg          GHS 250                 6.0
# 5          120/80     75 kg          GHS 150                 8.0
# 6           95/60     55 KG          GHS 100                10.0
# 7          150/95      82kg          GHS 150                 NaN
# 8          125/82     68 kg          GHS 200                 8.0
# 9             NaN     90 KG          GHS 250                 7.0
# 10         135/88      73kg          GHS 150                 9.0
# 11         115/75     58 kg           GHS100                 NaN
# 12        160/100     85 KG          GHS 200                 6.0
# 13         100/65      50kg          GHS 150                 9.0
# 14        175/105     92 kg          GHS 250                 5.0
# 15         128/84     65 KG          GHS 100                 8.0
# 16         118/78      78kg          GHS 200                 NaN
# 17         145/92     72 kg           GHS150                 7.0
# 18         108/68     60 KG          GHS 250                 9.0
# 19        165/102      88kg          GHS 100                 6.0
# 20         122/79     70 kg          GHS 200                 8.0
# 21            NaN     85 KG          GHS 150                 NaN
# 22         138/86      76kg           GHS250                 7.0
# 23         112/72     55 kg          GHS 100                 9.0
# 24         155/98     90 KG          GHS 200                 5.0
# 25         126/83      68kg          GHS 150                 8.0
# 26            NaN     60 kg          GHS 250                 NaN
# 27         132/87     72 KG           GHS100                 9.0
# 28         105/70      53kg          GHS 200                 6.0
# 29        170/108     87 kg          GHS 150                 7.0
# 30         124/81     71 KG          GHS 250                 8.0
# 31          98/62      57kg          GHS 100                 NaN
# 32         148/94     84 kg           GHS200                 7.0
# 33            NaN     63 KG          GHS 150                 9.0
# 34         130/85      76kg          GHS 250                 6.0
#
#     wait_time_min      city insurance
# 0            25.0     Accra       Yes
# 1            15.0    kumasi        no
# 2            45.0      TEMA       YES
# 3             NaN     Accra        No
# 4            60.0  Takoradi       yes
# 5            25.0     Accra       Yes
# 6            10.0    KUMASI        NO
# 7            50.0      tema       yes
# 8            30.0     accra        No
# 9             NaN  Takoradi       YES
# 10           35.0    Kumasi        no
# 11           20.0     ACCRA       Yes
# 12           55.0      Tema        NO
# 13           12.0    kumasi       yes
# 14           70.0     Accra        No
# 15            NaN  TAKORADI       YES
# 16           28.0     accra        no
# 17           40.0    Kumasi       Yes
# 18           18.0      TEMA        NO
# 19           65.0     accra       yes
# 20           32.0  takoradi        No
# 21            NaN     Accra       YES
# 22           42.0    KUMASI        no
# 23           22.0      tema       Yes
# 24           58.0     ACCRA        NO
# 25           30.0    Kumasi       yes
# 26           15.0  Takoradi        No
# 27            NaN     ACCRA       YES
# 28           48.0    kumasi        no
# 29           25.0      Tema       Yes
# 30           38.0     accra        NO
# 31           20.0  Takoradi       yes
# 32           52.0     ACCRA        No
# 33            NaN    kumasi       YES
# 34           33.0      TEMA        no
