# %%
import numpy as np
import pandas as pd

values = np.random.rand(5,3)

df = pd.DataFrame(
    values,
    columns=["A", "B", "C"],
    index=["r1", "r2", "r3", "r4", "r5"]
)

df
# Out:
#            A         B         C
# r1  0.151033  0.152228  0.204938
# r2  0.312934  0.336335  0.109705
# r3  0.794884  0.808772  0.597553
# r4  0.838583  0.044556  0.800518
# r5  0.753592  0.841699  0.623313
