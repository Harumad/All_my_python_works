# %%
name ="haruna"
age= 25

print(f"My name is {name},I am {age}years")
# Out:
# My name is haruna,I am 25years

# %%
a=5
b=4
c=6

print(a+b)
print(c-a)
print(c*a)
# Out:
# 9
# 1
# 30

# %%
user= "haruna"
print(f"Hello {user}!"" ""welcome back")
# Out:
# Hello haruna! welcome back

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def countEvenbUN()
    TOTAL=0
    
    for i in range (1,50)
   i=i%2==0

# %%
num=[1,2,3,4,5,6,7,8,9]
def listsum(numbers):
    total=o
    for num in numbers:
        total +=num
        return total
    listsum(numbers)
