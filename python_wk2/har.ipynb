# %%
print ("name")
# Out:
# name

# %%
language = ["javascript", "python", "java", "c++", "ruby", "go"]
print ("first three", language [:3])
# Out:
# first three ['javascript', 'python', 'java']

# %%
language = ["javascript", "python", "java", "c++", "ruby", "go"]
print ("last two", language[-2:])
# Out:
# last two ['ruby', 'go']

# %%
language = ["javascript", "python", "java", "c++", "ruby", "go"]
language.append("rust")
print ("after append", language)
# Out:
# after append ['javascript', 'python', 'java', 'c++', 'ruby', 'go', 'rust']

# %%
language = ["javascript", "python", "java", "c++", "ruby", "go"]
language.insert (1, "typescript")
print ("after insert:", language)
# Out:
# after insert: ['javascript', 'typescript', 'python', 'java', 'c++', 'ruby', 'go']

# %%
language = ["javascript", "python", "java", "c++", "ruby", "go"]
language.remove ("java")
print ("after remove:", language)
# Out:
# after remove: ['javascript', 'python', 'c++', 'ruby', 'go']

# %%
language = ["javascript", "python", "java", "c++", "ruby", "go"]
print ("final length:", len(language))
# Out:
# final length: 6

# %%
language=()
