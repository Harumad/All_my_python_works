# %% [markdown]
# Exercise 1

# %% [markdown]
# 🌾  Agriculture — Kumasi Market Crop Tracker

# %%
# Create a list of 6 crop prices in GHS. Use slicing to print only the first 3 prices
crop_price = [24,54,21,26,85,34,22,73,43,25]
print("first 3 prices:",crop_price[0:3])

# Use negative indexing to get the last price. Reverse the list with [::-1]. Find max, min, average
last_price = crop_price[-1]
reversed = crop_price[::-1]
maxed = max(crop_price)
mined = min(crop_price)
average = sum(crop_price) / len(crop_price)

print("last price:",last_price)
print("Reverse:",reversed)
print("maximum:",maxed)
print("minimum:",mined)
print("Average:",average)

#  Create a tuple for the market location: (name, city, lat, lng). 
market_location = ("name", "city", "lat", "lng")

# Unpack it into 4 variables
name, city, lat, lng = market_location
print(f"Unpacked: {name}, {city}, {lat}, {lng}")

# Create a dictionary for one crop: {name, price_ghs, region, harvest_month, quantity_kg}
one_crop = {
    "name": "Plantain",
    "price_ghs": 73,
    "region": "Greater Accra",
    "harvest_month": "June",
    "quantity_kg": 34.38,
}

# Use a list comprehension to get only crops with price > 20 from your list
crop = [crop_prices for crop_prices in crop_price if crop_prices > 20]
print(f"Crop prices greater than 20: {crop}")

# Use a list comprehension to convert all prices from GHS to USD (divide by 14.5)
prices = [price / 14.5 for price in crop_price]
print(f"From GHC To USD: {prices}")
# Out:
# first 3 prices: [24, 54, 21]
# last price: 25
# Reverse: [25, 43, 73, 22, 34, 85, 26, 21, 54, 24]
# maximum: 85
# minimum: 21
# Average: 40.7
# Unpacked: name, city, lat, lng
# Crop prices greater than 20: [24, 54, 21, 26, 85, 34, 22, 73, 43, 25]
# From GHC To USD: [1.6551724137931034, 3.7241379310344827, 1.4482758620689655, 1.793103448275862, 5.862068965517241, 2.3448275862068964, 1.5172413793103448, 5.0344827586206895, 2.9655172413793105, 1.7241379310344827]

# %% [markdown]
# Exercise 2

# %% [markdown]
# 💸  FinTech — MoMo Transaction Processor

# %% [markdown]
# Build a Mobile Money data system that uses every structure and control flow tool from today.

# %%
# 1.  Create a list of 8 transaction amounts (mix positive and negative). 
transaction_amounts = [7000, 453, -324, -964, 875, -389, 409, 890]

# Find total, max, min
total = sum(transaction_amounts)
maximum = max(transaction_amounts)
minimum = min(transaction_amounts)

print("Total:",total)
print("Maximum:",maximum)
print("Minimum:",minimum)

# 2.  Use a conditional (if/elif/else) to classify account status based on balance: critical/low/healthy
for transaction_amount in transaction_amounts:
    if transaction_amount <= 0:
        print(f"{transaction_amount} is Critical")
    elif transaction_amount > 0 and transaction_amount <= 500:
        print(f"{transaction_amount} is Low")
    else:
        print(f"{transaction_amount} is Healthy")  
     
      
# 3.  Use  if not transactions:  (Truthiness check) to handle the case of an empty transaction list
if not transaction_amounts:
    print("No transactions available")
else:
    print("transactions found")    

# 4.  Create a dict for a MoMo account. Use .get() for safe access. Loop over .items() to print all fields
momo_account = {
    "name": "Isaac",
    "number": 551245547,
    "pin": 8429
}
print(momo_account.items())
print(momo_account.get(name))

# 5.  Create sets for MTN and Vodafone subscribers. Find shared subscribers using intersection
mtn = {"Isaac", "Kojo", "Ama", "Adjoa", "Menu", "Yaw"}
vodafone = {"Kojo", "Mensah", "Isaac", "Pat", "Eli", "Kofi"}
shared = mtn.intersection(vodafone)
print(shared)

# 6.  Use a list comprehension to filter only deposits (positive amounts) from your transaction list
deposites = [positive for positive in transaction_amounts if positive > 0]
print(deposites)
# Out:
# Total: 7950
# Maximum: 7000
# Minimum: -964
# 7000 is Healthy
# 453 is Low
# -324 is Critical
# -964 is Critical
# 875 is Healthy
# -389 is Critical
# 409 is Low
# 890 is Healthy
# transactions found
# dict_items([('name', 'Isaac'), ('number', 551245547), ('pin', 8429)])
# Isaac
# {'Isaac', 'Kojo'}
# [7000, 453, 875, 409, 890]

# %%
# 1.  Create a list of 6 patient triage scores (0–100). Use loops + enumerate() to print ranked list
patient = [84, 32, 65, 12, 32, 54]
for i, patients in enumerate(patient):
    print(f"index {i}, ranked list {patients}")

# 2.  Use a conditional to classify each score: Critical(≥80) · Urgent(≥60) · Standard(≥40) · Routine
for score in patient:
    if score >= 80:
        print(f"{score} is Critical")
    elif score >= 60:
        print(f"{score} is Urgent")   
    elif score >= 40:
        print(f"{score} is Standard")
    else:
        print(f"{score} is Normal")         

# 3.  Create a tuple for each patient's fixed data: (patient_id, blood_type, date_of_birth) — why tuple?
patients = ("patient_id", "blood_type", "date_of_birth")
# 4.  Create a set of diagnoses from 8 patients (include repeats). Show how set removes duplicates
setA = {24, 64, 76, 23, 76, 23, 78, 42}
setB = {34, 56, 23, 98, 35, 75, 24, 78}
trans = setA.intersection(setB)
print(trans)
# 5.  Use zip() to pair patient_names list with triage_scores list. Print each pair with enumerate()

# 6.  Use a list comprehension to get names of all Critical patients (score >= 80) — Ghana hospital context
# Out:
# index 0, ranked list 84
# index 1, ranked list 32
# index 2, ranked list 65
# index 3, ranked list 12
# index 4, ranked list 32
# index 5, ranked list 54
# 84 is Critical
# 32 is Normal
# 65 is Urgent
# 12 is Normal
# 32 is Normal
# 54 is Standard
# {24, 78, 23}
