# %%
import pandas as pd

# %%
df = pd.read_csv("format.csv")

# %%
print(df)
# Out:
#     Name  Age             Email  Country Salary
# 0  Isaac    17  isaac@email.com    Ghana   2000
# 1   John         john@email.com      USA   3000
# 2   mary    25   MARY@email.com       uk
# 3  Isaac    17  isaac@email.com    Ghana   2000
# 4    NaN    30     noemail@.com  Nigeria   4000
# 5  Peter   200      peter@email    Kenya   5000
# 6   Anna    22   anna@email.com            3500
# 7  Kwame   28   kwame@email.com    Ghana    NaN

# %%
print(df.isnull())
# Out:
#     Name   Age   Email  Country  Salary
# 0  False  False  False    False   False
# 1  False  False  False    False   False
# 2  False  False  False    False   False
# 3  False  False  False    False   False
# 4   True  False  False    False   False
# 5  False  False  False    False   False
# 6  False  False  False    False   False
# 7  False  False  False    False    True

# %%
print(df.isnull().sum())
# Out:
# Name       1
#  Age       0
# Email      0
# Country    0
# Salary     1
# dtype: int64

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
print(df.duplicated().sum(),"Duplicates found")
# Out:
# 1 Duplicates found

# %%
df.columns
# Out:
# Index(['Name', ' Age ', 'Email', 'Country', 'Salary'], dtype='str')

# %%
print(df)
# Out:
#     Name  Age             Email  Country Salary
# 0  Isaac    17  isaac@email.com    Ghana   2000
# 1   John         john@email.com      USA   3000
# 2   mary    25   MARY@email.com       uk
# 3  Isaac    17  isaac@email.com    Ghana   2000
# 4    NaN    30     noemail@.com  Nigeria   4000
# 5  Peter   200      peter@email    Kenya   5000
# 6   Anna    22   anna@email.com            3500
# 7  Kwame   28   kwame@email.com    Ghana    NaN

# %%
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
print(df)
# Out:
#     Name  Age             Email  Country Salary
# 0  Isaac    17  isaac@email.com    Ghana   2000
# 1   John         john@email.com      USA   3000
# 2   mary    25   MARY@email.com       uk
# 4    NaN    30     noemail@.com  Nigeria   4000
# 5  Peter   200      peter@email    Kenya   5000
# 6   Anna    22   anna@email.com            3500
# 7  Kwame   28   kwame@email.com    Ghana    NaN

# %%
df.loc[4,"Name"] = "Kodjo"

# %%
print(df)
# Out:
#     Name  Age             Email  Country Salary
# 0  Isaac    17  isaac@email.com    Ghana   2000
# 1   John         john@email.com      USA   3000
# 2   mary    25   MARY@email.com       uk
# 4  Kodjo    30     noemail@.com  Nigeria   4000
# 5  Peter   200      peter@email    Kenya   5000
# 6   Anna    22   anna@email.com            3500
# 7  Kwame   28   kwame@email.com    Ghana    NaN

# %%
print(df.isnull().sum())
# Out:
# Name       0
#  Age       0
# Email      0
# Country    0
# Salary     1
# dtype: int64

# %%
print(df)
# Out:
#     Name  Age             Email  Country Salary
# 0  Isaac    17  isaac@email.com    Ghana   2000
# 1   John         john@email.com      USA   3000
# 2   mary    25   MARY@email.com       uk
# 4  Kodjo    30     noemail@.com  Nigeria   4000
# 5  Peter   200      peter@email    Kenya   5000
# 6   Anna    22   anna@email.com            3500
# 7  Kwame   28   kwame@email.com    Ghana    NaN

# %%
df["Salary"] = pd.to_numeric(df["Salary"],errors="coerce")

df.loc[7,"Salary"] = 5300

# %%
print(df)
# Out:
#     Name  Age             Email  Country  Salary
# 0  Isaac    17  isaac@email.com    Ghana  2000.0
# 1   John         john@email.com      USA  3000.0
# 2   mary    25   MARY@email.com       uk     NaN
# 4  Kodjo    30     noemail@.com  Nigeria  4000.0
# 5  Peter   200      peter@email    Kenya  5000.0
# 6   Anna    22   anna@email.com           3500.0
# 7  Kwame   28   kwame@email.com    Ghana  5300.0

# %%
print(df.columns)
# Out:
# Index(['Name', ' Age ', 'Email', 'Country', 'Salary'], dtype='str')

# %%
print(df.isnull().sum())
# Out:
# Name       0
#  Age       0
# Email      0
# Country    0
# Salary     1
# dtype: int64

# %%
print(df)
# Out:
#     Name  Age             Email  Country  Salary
# 0  Isaac    17  isaac@email.com    Ghana  2000.0
# 1   John         john@email.com      USA  3000.0
# 2   mary    25   MARY@email.com       uk     NaN
# 4  Kodjo    30     noemail@.com  Nigeria  4000.0
# 5  Peter   200      peter@email    Kenya  5000.0
# 6   Anna    22   anna@email.com           3500.0
# 7  Kwame   28   kwame@email.com    Ghana  5300.0

# %%
df.loc[2,"Salary"] = 7356
print(df)
# Out:
#     Name  Age             Email  Country  Salary
# 0  Isaac    17  isaac@email.com    Ghana  2000.0
# 1   John         john@email.com      USA  3000.0
# 2   mary    25   MARY@email.com       uk  7356.0
# 4  Kodjo    30     noemail@.com  Nigeria  4000.0
# 5  Peter   200      peter@email    Kenya  5000.0
# 6   Anna    22   anna@email.com           3500.0
# 7  Kwame   28   kwame@email.com    Ghana  5300.0

# %%
print(df.isnull())
# Out:
#     Name   Age   Email  Country  Salary
# 0  False  False  False    False   False
# 1  False  False  False    False   False
# 2  False  False  False    False   False
# 4  False  False  False    False   False
# 5  False  False  False    False   False
# 6  False  False  False    False   False
# 7  False  False  False    False   False

# %%
df.dtypes
# Out:
# Name           str
#  Age           str
# Email          str
# Country        str
# Salary     float64
# dtype: object

# %%
print(df)
# Out:
#     Name  Age             Email  Country  Salary
# 0  Isaac    17  isaac@email.com    Ghana  2000.0
# 1   John         john@email.com      USA  3000.0
# 2   mary    25   MARY@email.com       uk  7356.0
# 4  Kodjo    30     noemail@.com  Nigeria  4000.0
# 5  Peter   200      peter@email    Kenya  5000.0
# 6   Anna    22   anna@email.com           3500.0
# 7  Kwame   28   kwame@email.com    Ghana  5300.0

# %%
df.loc[6,"Country"] = "Uganda"

# %%
print(df)
# Out:
#     Name  Age             Email  Country  Salary
# 0  Isaac    17  isaac@email.com    Ghana  2000.0
# 1   John         john@email.com      USA  3000.0
# 2   mary    25   MARY@email.com       uk  7356.0
# 4  Kodjo    30     noemail@.com  Nigeria  4000.0
# 5  Peter   200      peter@email    Kenya  5000.0
# 6   Anna    22   anna@email.com   Uganda  3500.0
# 7  Kwame   28   kwame@email.com    Ghana  5300.0

# %%
df.dtypes
# Out:
# Name           str
#  Age           str
# Email          str
# Country        str
# Salary     float64
# dtype: object

# %%
df[" Age "] = df[" Age "].str.strip()

# %%
print(df)
# Out:
#     Name  Age             Email  Country  Salary
# 0  Isaac    17  isaac@email.com    Ghana  2000.0
# 1   John         john@email.com      USA  3000.0
# 2   mary    25   MARY@email.com       uk  7356.0
# 4  Kodjo    30     noemail@.com  Nigeria  4000.0
# 5  Peter   200      peter@email    Kenya  5000.0
# 6   Anna    22   anna@email.com   Uganda  3500.0
# 7  Kwame    28  kwame@email.com    Ghana  5300.0

# %%
print(df.columns)
# Out:
# Index(['Name', ' Age ', 'Email', 'Country', 'Salary'], dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
print(df)
# Out:
#     Name  Age            Email  Country  Salary
# 0  Isaac   17  isaac@email.com    Ghana  2000.0
# 1   John        john@email.com      USA  3000.0
# 2   mary   25   MARY@email.com       uk  7356.0
# 4  Kodjo   30     noemail@.com  Nigeria  4000.0
# 5  Peter  200      peter@email    Kenya  5000.0
# 6   Anna   22   anna@email.com   Uganda  3500.0
# 7  Kwame   28  kwame@email.com    Ghana  5300.0

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Email', 'Country', 'Salary'], dtype='str')

# %%
df["Age"] = pd.to_numeric(df["Age"],errors="coerce")

# %%
print(df)
# Out:
#     Name    Age            Email  Country  Salary
# 0  Isaac   17.0  isaac@email.com    Ghana  2000.0
# 1   John    NaN   john@email.com      USA  3000.0
# 2   mary   25.0   MARY@email.com       uk  7356.0
# 4  Kodjo   30.0     noemail@.com  Nigeria  4000.0
# 5  Peter  200.0      peter@email    Kenya  5000.0
# 6   Anna   22.0   anna@email.com   Uganda  3500.0
# 7  Kwame   28.0  kwame@email.com    Ghana  5300.0

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
print(df)
# Out:
#     Name    Age            Email  Country  Salary
# 0  Isaac   17.0  isaac@email.com    Ghana  2000.0
# 1   John   26.5   john@email.com      USA  3000.0
# 2   mary   25.0   MARY@email.com       uk  7356.0
# 4  Kodjo   30.0     noemail@.com  Nigeria  4000.0
# 5  Peter  200.0      peter@email    Kenya  5000.0
# 6   Anna   22.0   anna@email.com   Uganda  3500.0
# 7  Kwame   28.0  kwame@email.com    Ghana  5300.0

# %%
df.loc[5,"Age"] = 25

# %%
print(df)
# Out:
#     Name   Age            Email  Country  Salary
# 0  Isaac  17.0  isaac@email.com    Ghana  2000.0
# 1   John  26.5   john@email.com      USA  3000.0
# 2   mary  25.0   MARY@email.com       uk  7356.0
# 4  Kodjo  30.0     noemail@.com  Nigeria  4000.0
# 5  Peter  25.0      peter@email    Kenya  5000.0
# 6   Anna  22.0   anna@email.com   Uganda  3500.0
# 7  Kwame  28.0  kwame@email.com    Ghana  5300.0

# %%
df.loc[2, "Email"] = "mary@email.com"
df.loc[4, "Email"] = "noemail@email.com"
df.loc[5, "Email"] = "peter@email.com"

# %%
print(df)
# Out:
#     Name   Age              Email  Country  Salary
# 0  Isaac  17.0    isaac@email.com    Ghana  2000.0
# 1   John  26.5     john@email.com      USA  3000.0
# 2   mary  25.0     mary@email.com       uk  7356.0
# 4  Kodjo  30.0  noemail@email.com  Nigeria  4000.0
# 5  Peter  25.0    peter@email.com    Kenya  5000.0
# 6   Anna  22.0     anna@email.com   Uganda  3500.0
# 7  Kwame  28.0    kwame@email.com    Ghana  5300.0

# %%
df.dtypes
# Out:
# Name           str
# Age        float64
# Email          str
# Country        str
# Salary     float64
# dtype: object

# %%
df["Age"] = df["Age"].astype(int)

# %%
df.dtypes
# Out:
# Name           str
# Age          int64
# Email          str
# Country        str
# Salary     float64
# dtype: object

# %%
print(df
)
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   mary   25     mary@email.com       uk  7356.0
# 4  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 5  Peter   25    peter@email.com    Kenya  5000.0
# 6   Anna   22     anna@email.com   Uganda  3500.0
# 7  Kwame   28    kwame@email.com    Ghana  5300.0

# %%
df.head()
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   mary   25     mary@email.com       uk  7356.0
# 4  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 5  Peter   25    peter@email.com    Kenya  5000.0

# %%
df.head()
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   mary   25     mary@email.com       uk  7356.0
# 4  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 5  Peter   25    peter@email.com    Kenya  5000.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     7 non-null      str
#  1   Age      7 non-null      int64
#  2   Email    7 non-null      str
#  3   Country  7 non-null      str
#  4   Salary   7 non-null      float64
# dtypes: float64(1), int64(1), str(3)
# memory usage: 636.0 bytes

# %%
pd.melt(df)
# Out:
#    variable              value
# 0      Name              Isaac
# 1      Name               John
# 2      Name               mary
# 3      Name              Kodjo
# 4      Name              Peter
# 5      Name               Anna
# 6      Name              Kwame
# 7       Age                 17
# 8       Age                 26
# 9       Age                 25
# 10      Age                 30
# 11      Age                 25
# 12      Age                 22
# 13      Age                 28
# 14    Email    isaac@email.com
# 15    Email     john@email.com
# 16    Email     mary@email.com
# 17    Email  noemail@email.com
# 18    Email    peter@email.com
# 19    Email     anna@email.com
# 20    Email    kwame@email.com
# 21  Country              Ghana
# 22  Country                USA
# 23  Country                 uk
# 24  Country            Nigeria
# 25  Country              Kenya
# 26  Country             Uganda
# 27  Country              Ghana
# 28   Salary             2000.0
# ...

# %%
df.pivot(index="Name", columns="Age", values="Email")
# Out:
# Age                 17              22               25              26  \
# Name
# Anna               NaN  anna@email.com              NaN             NaN
# Isaac  isaac@email.com             NaN              NaN             NaN
# John               NaN             NaN              NaN  john@email.com
# Kodjo              NaN             NaN              NaN             NaN
# Kwame              NaN             NaN              NaN             NaN
# Peter              NaN             NaN  peter@email.com             NaN
# mary               NaN             NaN   mary@email.com             NaN
#
# Age                 28                 30
# Name
# Anna               NaN                NaN
# Isaac              NaN                NaN
# John               NaN                NaN
# Kodjo              NaN  noemail@email.com
# Kwame  kwame@email.com                NaN
# Peter              NaN                NaN
# mary               NaN                NaN

# %%
df.pivot(index="Name", columns="Country", values="Salary")
# Out:
# Country   Ghana   Kenya  Nigeria     USA  Uganda      uk
# Name
# Anna        NaN     NaN      NaN     NaN  3500.0     NaN
# Isaac    2000.0     NaN      NaN     NaN     NaN     NaN
# John        NaN     NaN      NaN  3000.0     NaN     NaN
# Kodjo       NaN     NaN   4000.0     NaN     NaN     NaN
# Kwame    5300.0     NaN      NaN     NaN     NaN     NaN
# Peter       NaN  5000.0      NaN     NaN     NaN     NaN
# mary        NaN     NaN      NaN     NaN     NaN  7356.0

# %%
df.describe()
# Out:
#              Age       Salary
# count   7.000000     7.000000
# mean   24.714286  4308.000000
# std     4.231402  1757.777384
# min    17.000000  2000.000000
# 25%    23.500000  3250.000000
# 50%    25.000000  4000.000000
# 75%    27.000000  5150.000000
# max    30.000000  7356.000000

# %%
df["Age"].mean()
# Out:
# np.float64(24.714285714285715)

# %%
df["Salary"].max()
# Out:
# np.float64(7356.0)

# %%
df["Name"].value_counts()
# Out:
# Name
# Isaac    1
# John     1
# mary     1
# Kodjo    1
# Peter    1
# Anna     1
# Kwame    1
# Name: count, dtype: int64

# %%
print(df)
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   mary   25     mary@email.com       uk  7356.0
# 4  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 5  Peter   25    peter@email.com    Kenya  5000.0
# 6   Anna   22     anna@email.com   Uganda  3500.0
# 7  Kwame   28    kwame@email.com    Ghana  5300.0

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Email', 'Country', 'Salary'], dtype='str')

# %%
df["Email"] = df["Email"].str.strip()

# %%
print(df)
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   mary   25     mary@email.com       uk  7356.0
# 4  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 5  Peter   25    peter@email.com    Kenya  5000.0
# 6   Anna   22     anna@email.com   Uganda  3500.0
# 7  Kwame   28    kwame@email.com    Ghana  5300.0

# %%
df["Name"] = df["Name"].str.title()

# %%
print(df)
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   Mary   25     mary@email.com       uk  7356.0
# 4  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 5  Peter   25    peter@email.com    Kenya  5000.0
# 6   Anna   22     anna@email.com   Uganda  3500.0
# 7  Kwame   28    kwame@email.com    Ghana  5300.0

# %%
df = df.reset_index(drop=True)

# %%
print(df)
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    Ghana  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   Mary   25     mary@email.com       uk  7356.0
# 3  Kodjo   30  noemail@email.com  Nigeria  4000.0
# 4  Peter   25    peter@email.com    Kenya  5000.0
# 5   Anna   22     anna@email.com   Uganda  3500.0
# 6  Kwame   28    kwame@email.com    Ghana  5300.0

# %%
df["Country"] = df["Country"].str.upper()

# %%
df.head()
# Out:
#     Name  Age              Email  Country  Salary
# 0  Isaac   17    isaac@email.com    GHANA  2000.0
# 1   John   26     john@email.com      USA  3000.0
# 2   Mary   25     mary@email.com       UK  7356.0
# 3  Kodjo   30  noemail@email.com  NIGERIA  4000.0
# 4  Peter   25    peter@email.com    KENYA  5000.0

# %%
df.to_csv("format_clean",index=False)
